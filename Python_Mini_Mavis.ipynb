# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Analyze data from NYC regents report by comparing one high school's mean test score for the common core algebra test in 2017 compared to the three specialized high schools

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested  Mean Score  \
# 0  Common Core Algebra  2017             4         NaN
# 1   Living Environment  2015            16        77.9
# 2   Living Environment  2016             9        74.0
# 3  Common Core Algebra  2016             3         NaN
# 4  Common Core Algebra  2017             2         NaN
#
#   Number Scoring Below 65 Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                       s                        s                          s
# 1                       1                      6.3                         15
# ...

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=212331, step=1)

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %%
df.loc[(df['School DBN']=='02M416') & (df['Mean Score'])]
# Out:
#        School DBN                    School Name School Level  \
# 1135       02M416  Eleanor Roosevelt High School  High school
# 1136       02M416  Eleanor Roosevelt High School  High school
# 1137       02M416  Eleanor Roosevelt High School  High school
# 1138       02M416  Eleanor Roosevelt High School  High school
# 1139       02M416  Eleanor Roosevelt High School  High school
# ...           ...                            ...          ...
# 144592     02M416  Eleanor Roosevelt High School  High school
# 144594     02M416  Eleanor Roosevelt High School  High school
# 144595     02M416  Eleanor Roosevelt High School  High school
# 144597     02M416  Eleanor Roosevelt High School  High school
# 144599     02M416  Eleanor Roosevelt High School  High school
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 1135          Algebra2/Trigonometry  2015           235        81.2
# 1136          Algebra2/Trigonometry  2016           141        83.0
# ...

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                    School Name  Year         Regents Exam  \
# 1138       02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21499      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21500      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57076      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57077      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105023     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105024     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144462     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144463     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144464     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144465     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# ...

# %%
drop_cols = ['Number Scoring Below 65',
       'Percent Scoring Below 65', 'Number Scoring 65 or Above',
       'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
       'Percent Scoring 80 or Above', 'Number Scoring CR',
       'Percent Scoring CR']

# %%
df.drop(drop_cols, inplace =True, axis=1)

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested  Mean Score
# 0  Common Core Algebra  2017             4         NaN
# 1   Living Environment  2015            16        77.9
# 2   Living Environment  2016             9        74.0
# 3  Common Core Algebra  2016             3         NaN
# 4  Common Core Algebra  2017             2         NaN

# %%
df.shape
# Out:
# (212331, 7)

# %%
df.isnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean Score
# 0              False        True
# 1              False       False
# 2              False       False
# ...

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                    School Name  Year         Regents Exam  \
# 1138       02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21499      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21500      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57076      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57077      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105023     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105024     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144462     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144463     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144464     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144465     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# ...

# %%
df['Mean Score']= pd.to_numeric(df['Mean Score'], errors ='coerce')

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                    School Name  Year         Regents Exam  \
# 1138       02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21499      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21500      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57076      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57077      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105023     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105024     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144462     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144463     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144464     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144465     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# ...

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']].mean()
# Out:
# Year          2017.000000
# Mean Score      85.611111
# dtype: float64

# %%
df.loc[(df['School DBN']== '02M475') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN             School Name  Year         Regents Exam  \
# 1515       02M475  Stuyvesant High School  2017  Common Core Algebra
# 22189      02M475  Stuyvesant High School  2017  Common Core Algebra
# 22190      02M475  Stuyvesant High School  2017  Common Core Algebra
# 58019      02M475  Stuyvesant High School  2017  Common Core Algebra
# 58020      02M475  Stuyvesant High School  2017  Common Core Algebra
# 105744     02M475  Stuyvesant High School  2017  Common Core Algebra
# 105745     02M475  Stuyvesant High School  2017  Common Core Algebra
# 145989     02M475  Stuyvesant High School  2017  Common Core Algebra
# 145990     02M475  Stuyvesant High School  2017  Common Core Algebra
# 145991     02M475  Stuyvesant High School  2017  Common Core Algebra
# 145992     02M475  Stuyvesant High School  2017  Common Core Algebra
# 145993     02M475  Stuyvesant High School  2017  Common Core Algebra
#
#         Mean Score
# 1515          93.9
# 22189          NaN
# ...

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                    School Name  Year         Regents Exam  \
# 1138       02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21499      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 21500      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57076      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 57077      02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105023     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 105024     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144462     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144463     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144464     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# 144465     02M416  Eleanor Roosevelt High School  2017  Common Core Algebra
# ...

# %%
df.loc[(df['School DBN']== '10X445') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                   School Name  Year         Regents Exam  \
# 6836       10X445  Bronx High School of Science  2017  Common Core Algebra
# 31845      10X445  Bronx High School of Science  2017  Common Core Algebra
# 71802      10X445  Bronx High School of Science  2017  Common Core Algebra
# 71803      10X445  Bronx High School of Science  2017  Common Core Algebra
# 115875     10X445  Bronx High School of Science  2017  Common Core Algebra
# 115876     10X445  Bronx High School of Science  2017  Common Core Algebra
# 165361     10X445  Bronx High School of Science  2017  Common Core Algebra
# 165362     10X445  Bronx High School of Science  2017  Common Core Algebra
# 165363     10X445  Bronx High School of Science  2017  Common Core Algebra
# 165364     10X445  Bronx High School of Science  2017  Common Core Algebra
# 165365     10X445  Bronx High School of Science  2017  Common Core Algebra
#
#         Mean Score
# 6836          92.4
# 31845         92.4
# ...

# %%
df.loc[(df['School DBN']== '13K430') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                     School Name  Year         Regents Exam  \
# 8585       13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 34940      13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 34941      13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 76283      13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 76284      13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 119222     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 119223     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 171935     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 171936     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 171937     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# 171938     13K430  Brooklyn Technical High School  2017  Common Core Algebra
# ...

# %%
# Comparing Eleanor Roosevelt High School and the three Specailized High School
# Comparing mean Common Core Algebra test score in 2017

# %%
#mean score for Stuyvesant 
df.loc[(df['School DBN']== '02M475') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2017.000000
# Total Tested      26.250000
# Mean Score        93.928571
# dtype: float64

# %%
#mean score for Eleanor Roosvelt 
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2017.000000
# Total Tested      22.500000
# Mean Score        85.611111
# dtype: float64

# %%
df.loc[(df['School DBN']== '02M416') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra')].mean()

# %%
#mean score for Brooklyn Tech
df.loc[(df['School DBN']== '13K430') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2017.000000
# Total Tested     159.583333
# Mean Score        87.450000
# dtype: float64

# %%
#mean score for Bronx Science
df.loc[(df['School DBN']== '10X445') & (df['Year']== 2017) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2017.000000
# Total Tested      57.727273
# Mean Score        92.745455
# dtype: float64

# %%
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
df = pd.DataFrame({'School':['Eleanor Roosevelt High School', 'Stuyvesant High School', 'Bronx High School of Science', 'Brooklyn Technical High School'], 'Common Core Algebra Score':[85.61, 93.92, 87.45, 92.74]})
ax = df.plot.bar(x='School', y='Common Core Algebra Score', rot=0)

# %%
#This analysis compares the mean common core algebra regents test score in 2017 between Eleanor Roosevelt High School and the three specialized public high schools, Stuyvesant, Bronx Science and Brooklyn Technical.  In 2017, the mean common core algebra test score test score for Eleanor Roosevelt High School is 85.61 and the mean common core algebra test score for Stuyvesant High School is 93.92, Bronx Science is 87.45 and Brooklyn Tech is 92.94. The mean test score for the common core algebra regents for the three specialized high schools are higher than Eleanor Roosevelt High School.
